# %% [markdown]
# Practice Questions:
#
# - Extract `"Python"` from "Hello, I love Python Programming"
# - Reverse the word "Hello" using slicing operator and loop.
# - For a table of length 5 feet and width 10 feet. Calculate the area.
# - Perform below operations in a given list: `["apple", "orange", "pineapple", "apple", "tomato", "banana", "orange"]`
#     - Find and remove the dublicate values
#     - Find the length of the list
#     - Remove "banana" from the list
#     - Find the number of "apple" in the list
# - For a set `a = {10, 11, 20, 50}` and `b = {20, 11, 55, 90, 22}`. Find:
#     - Numbers in a but not in b
#     - Numbers in both a and b
#     - Numbers in a or b but not both
# - Remove odd number from `[1, 2, 3, 4, 5, 6, 7]` list.
# - Sum all the items in the list `[1, 2, 3, 4, 5, 6, 7]` without built-in methods.
# - Find the index of 4 in list `[1, 2, 3, 4, 5, 6, 7]`
# - Find the longest item in the list `['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']`
# - Concatinate 'A ' to begining of all the items in the list `['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']`
# - Check if list is empty
# - Insert 7 to second last element of `[1, 2, 3, 4, 5, 6, 8]` list.
# - Check if an element exist in a tuple
# - Find a repeacted item 2 in a tuple `2, 4, 5, 6, 2, 3, 4, 4, 7`.
# - For two set {'apple', 'orange', 'pear', 'pineapple'} and {'kiwi', 'orange', 'apple', 'guwava'}, find:
#     1. Intersection
#     2. Union
#     3. Difference
#     4. Symmetric Difference
# - For dictornary:
#     ```python
#     contact = {
#         'Samar Shrestha': 9840298755,
#         'Ishwar Chapagain': 98651201503,
#         'Dipesh Wagle': 9863331239,
#     }
#     ```
#     - Check if `Ishwar Chapagain` exists in contact
#     - Concatenate below dictionary to contact:
#     ```python
#     new_contact = {
#         'John Anderson': 98546625,
#         'Shyam Pradhan': 98751478556,
#         'Krishna Ghimire': 984656221546,
#         'Ram Kasula': 9840298755,
#     }
#     ```
#     - Remove Shyam Pradhan from the above dict.
#     - Sort the above dict by Keys
#     - Check if dict is empty
#     - Find common keys between above two dict.
#     - Remove space from keys in above dictionary.
#     - Count the number of items in the dict.
# - Using list comprehension, print a table of 2
# - Using dictionary comprehension, print a table of 5
# - Calculate final amount for individual items following transaction using comprehension techniques:
#     ```python
#     transactions = {
#         'Corn Flakes': 1001/1,
#         'Fruit Cake': 55.5,
#         'Apple Kashmiri 1KG': 500,
#         'Milk 1Packet': 40
#     }
#     tax_rate = 13
#     ```
#     - From above, assuming discount rate is 10%, calculate the final prices for individual items and total amount.
# - Find length of each word in Today is my lucky day using dictonary comprehension
# - Find numbers which is divisible by 2 but not by 5 using list comprehension upto 100
# - Print below pattern using nested loop:
#     ```
#     *
#     * *
#     * * *
#     * * * *
#     * * * * *
#     ```
# - Calculate the individual expense by an individual, total expense and payable amount for each member from below data structures using loop:
#     ```python
#     expenses = {
#         'Samar': {
#             'BBQ': 280,
#             'Coffee': 120,
#             'Milk': 160,
#             'Momo': 200,
#             'Eggs': 50,
#         },
#         'Sugam': {
#             'Water': 30,
#         },
#         'Pabitra': {
#             'Chocolate': 90,
#         },
#         'Angila': {
#             'Icecream':500,
#         },
#     }
#     ```
# - Convert the above expenses dictionary keys to list using loop
# - A class named `Circle` constructed by a radius and two methods which will compute the area and the perimeter of a circle.
# - A class which has two methods `get_string` and `print_string`. `get_string` accept a string from the user and `print_string` print the string in upper case.
# - Create a `Cricle` class and intialize it with `radius`. Make two methods `get_area` and `get_circumference` inside this class.
# - Create a class named `Dog` which has instance attributes name, breed, life_expectancy, origin_place and class attribute species. Add instance method `bark(), eat(), description()` methods.
# - Create a function that will accept `n` words and returns concatenated stirngs. For example: `form_a_sentence("hello", "world")` will return `"hello world"`
